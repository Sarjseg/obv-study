# %%
import sys
import os
from pathlib import Path
config_path = str(Path(os.path.abspath('')).parent)
sys.path.append(config_path)
from src.obva import StockAnalyzerOBV
from src.utils import setup_logging
from config import LOGGING_CONFIG
setup_logging(LOGGING_CONFIG)

# %%
stock_to_analyze =  'GRF.MC' # 'CABK.MC' # 'IDR.MC' # 
stock_analysis = StockAnalyzerOBV(stock_to_analyze)
stock_analysis.detect_acc(period='2y')
stock_analysis.plot_data(dist_show=False, save_html = True)
# Out:
# 2025-11-08 12:32:10 - src.obva - INFO - Initialized StockAnalyzerOBV for ticker: GRF.MC
# 2025-11-08 12:32:10 - src.obva - INFO - StockAnalyzerOBV.detect_acc(period='2y')
# 2025-11-08 12:32:11 - src.obva - INFO - Detected 14 accumulation days and 18 distribution days
# 2025-11-08 12:32:11 - src.obva - INFO - StockAnalyzerOBV.plot_data(dist_show=False, save_html=True)
# 2025-11-08 12:32:11 - src.obva - INFO - Plot saved to c:\Users\admin\OneDrive\Documents\Programacion\Python\Python projects\obv_study\results

# %%
# parameters to backtest
days_holding = 45        
profit_target = 0.15  
stop_loss = 0.05    
stock_analysis.calc_pnl_holding(hold_period=days_holding, bool_detect_buy=False, save_results=True)
stock_analysis.calc_pnl_sl(profit_target=profit_target, stop_loss=stop_loss, bool_detect_buy=False, save_results=True)
# Out:
# 2025-11-08 12:32:11 - src.obva - INFO - StockAnalyzerOBV.calc_pnl_holding(hold_period=45, bool_detect_buy=False, save_results=True)
# 2025-11-08 12:32:11 - src.obva - INFO - Holding strategy results saved to c:\Users\admin\OneDrive\Documents\Programacion\Python\Python projects\obv_study\results
# 2025-11-08 12:32:11 - src.obva - INFO - StockAnalyzerOBV.calc_pnl_sl(profit_target=0.15, stop_loss=0.05, bool_detect_buy=False, save_results=True)
# 2025-11-08 12:32:11 - src.obva - INFO - Stop Loss strategy results saved to c:\Users\admin\OneDrive\Documents\Programacion\Python\Python projects\obv_study\results

# %%
stock_analysis.summary_holding()
# Out:
# Strategy 1: holding 45 days for GRF.MC
# Mean PnL per unit: -0.40
# Mean rate of return: -1.05
# Number of successes: 7 de 14
# Details:
# shape: (14, 6)
# ┌─────────────────────┬───────────┬─────────────────────┬────────────┬───────────┬─────────────┐
# │ date_entry          ┆ price_buy ┆ date_sell           ┆ price_sell ┆ PnL_pu    ┆ rate_return │
# │ ---                 ┆ ---       ┆ ---                 ┆ ---        ┆ ---       ┆ ---         │
# │ datetime[μs]        ┆ f64       ┆ datetime[μs]        ┆ f64        ┆ f64       ┆ f64         │
# ╞═════════════════════╪═══════════╪═════════════════════╪════════════╪═══════════╪═════════════╡
# │ 2024-01-02 00:00:00 ┆ 14.687943 ┆ 2024-03-05 00:00:00 ┆ 7.683989   ┆ -7.003954 ┆ -47.685058  │
# │ 2024-01-11 00:00:00 ┆ 9.789327  ┆ 2024-03-14 00:00:00 ┆ 7.120588   ┆ -2.668739 ┆ -27.26172   │
# │ 2024-03-04 00:00:00 ┆ 7.988422  ┆ 2024-05-09 00:00:00 ┆ 9.253602   ┆ 1.26518   ┆ 15.837673   │
# ...

# %%
stock_analysis.summary_sl()
# Out:
# Strategy 2: profit target 15.00%, stop loss 5.00% for GRF.MC
# Mean PnL per unit: -0.49
# Mean rate of return: -4.14
# Operations 'Take Profit' (15.00%%): 3
# Operations 'Stop Loss' (5.00%%): 11
# Details:
# shape: (14, 7)
# ┌────────────────┬───────────┬────────────────┬────────────┬─────────────┬───────────┬─────────────┐
# │ date_entry     ┆ price_buy ┆ day_sell       ┆ price_sell ┆ reason      ┆ PnL_pu    ┆ rate_return │
# │ ---            ┆ ---       ┆ ---            ┆ ---        ┆ ---         ┆ ---       ┆ ---         │
# │ datetime[μs]   ┆ f64       ┆ datetime[μs]   ┆ f64        ┆ str         ┆ f64       ┆ f64         │
# ╞════════════════╪═══════════╪════════════════╪════════════╪═════════════╪═══════════╪═════════════╡
# │ 2024-01-02     ┆ 14.687943 ┆ 2024-01-09     ┆ 10.427846  ┆ Stop Loss   ┆ -4.260097 ┆ -29.004039  │
# │ 00:00:00       ┆           ┆ 00:00:00       ┆            ┆             ┆           ┆             │
# ...
